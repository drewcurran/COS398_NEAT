# %%
import sys
sys.path.append('C:\\Users\\drewc\\Documents\\GitHub\\COS398_CatanAI\\')
sys.path.append('C:\\Users\\denis\\Documents\\GitHub\\COS398_CatanAI\\')

# %%
from matplotlib import pyplot as plt
import pickle

# %%
from catanatron import RandomPlayer, Color

# %%
from Catan.catan_players import NEATPlayer
from Catan.catan_training import play_batch

# %%
with open('config.pickle', 'rb') as handle:
    population_size, games_per_player = pickle.load(handle)

# %%
with open('population.pickle', 'rb') as handle:
    population = pickle.load(handle)
best_agent = population.species[0].players[0]
best_agent.print_state()
best_agent.draw_state()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\denis\Documents\GitHub\COS398_CatanAI\Catan\progress\nospecies\catan_stats.ipynb Cell 6 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> with open('population.pickle', 'rb') as handle:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     population = pickle.load(handle)
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> best_agent = population.species[0].players[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> best_agent.print_state()
#
# ModuleNotFoundError: No module named 'NEAT.connection_history'

# %%
with open('agent_wins.pickle', 'rb') as handle:
    agent_wins = pickle.load(handle)
plt.plot(range(1, len(agent_wins) + 1), agent_wins, color='Orange')
plt.show()

# %%
with open('num_innovations.pickle', 'rb') as handle:
    num_innovations = pickle.load(handle)
plt.plot(range(1, len(num_innovations) + 1), num_innovations, color='Orange')
plt.show()

# %%
with open('num_species.pickle', 'rb') as handle:
    num_species = pickle.load(handle)
plt.plot(range(1, len(num_species) + 1), num_species, color='Orange')
plt.show()

# %%
with open('avg_fitness.pickle', 'rb') as handle:
    avg_fitness = pickle.load(handle)
plt.plot(range(1, len(avg_fitness) + 1), avg_fitness, color='Orange')
plt.show()

# %%
with open('max_fitness.pickle', 'rb') as handle:
    max_fitness = pickle.load(handle)
plt.plot(range(1, len(max_fitness) + 1), max_fitness, color='Orange')
plt.show()

# %%
best_agent = population.species[0].players[0]

game_agents = [NEATPlayer(Color.ORANGE), RandomPlayer(Color.RED), RandomPlayer(Color.BLUE), RandomPlayer(Color.WHITE)]
agent = game_agents[0]
agent.agent = best_agent

play_batch(1000, game_agents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\denis\Documents\GitHub\COS398_CatanAI\Catan\progress\nospecies\catan_stats.ipynb Cell 12 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> best_agent = population.species[0].players[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> game_agents = [NEATPlayer(Color.ORANGE), RandomPlayer(Color.RED), RandomPlayer(Color.BLUE), RandomPlayer(Color.WHITE)]
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Catan/progress/nospecies/catan_stats.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> agent = game_agents[0]
#
# NameError: name 'population' is not defined
