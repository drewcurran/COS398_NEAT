# %%
import sys
sys.path.append('C:\\Users\\drewc\\Documents\\GitHub\\COS398_CatanAI')
sys.path.append('C:\\Users\\denis\\Documents\\GitHub\\COS398_CatanAI')

# %%
from matplotlib import pyplot as plt
import pickle

# %%
from Circuit_Design.circuit_games import Add4Game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\denis\Documents\GitHub\COS398_CatanAI\Circuit_Design\add4\add4_stats.ipynb Cell 3 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/denis/Documents/GitHub/COS398_CatanAI/Circuit_Design/add4/add4_stats.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from Circuit_Design.circuit_games import Add4Game
#
# ModuleNotFoundError: No module named 'Circuit_Design'

# %%
with open('config.pickle', 'rb') as handle:
    population_size, games_per_player = pickle.load(handle)

# %%
with open('population.pickle', 'rb') as handle:
    population = pickle.load(handle)
best_agent = population.species[0].players[0]
best_agent.nn.print_state()
best_agent.nn.draw_state(numbers=False)
# Out:
# 	State
# 	Nodes: 14 (2), {0: [Node(0,L=0), Node(1,L=0), Node(2,L=0), Node(3,L=0), Node(4,L=0), Node(5,L=0), Node(6,L=0), Node(7,L=0), Node(8,L=0)], 1: [Node(9,L=1), Node(10,L=1), Node(11,L=1), Node(12,L=1), Node(13,L=1)]}
# 	Connections: 13, [Gene(Node(3,L=0)->Node(12,L=1),W=0.4680,I=2,E=1), Gene(Node(2,L=0)->Node(9,L=1),W=-0.2326,I=130,E=1), Gene(Node(1,L=0)->Node(9,L=1),W=0.9549,I=223,E=1), Gene(Node(2,L=0)->Node(11,L=1),W=0.2901,I=1018,E=1), Gene(Node(7,L=0)->Node(11,L=1),W=0.0251,I=1320,E=1), Gene(Node(6,L=0)->Node(13,L=1),W=0.7374,I=3132,E=1), Gene(Node(5,L=0)->Node(10,L=1),W=0.8590,I=5039,E=1), Gene(Node(1,L=0)->Node(13,L=1),W=-0.7950,I=6131,E=1), Gene(Node(1,L=0)->Node(12,L=1),W=-0.9335,I=9629,E=1), Gene(Node(4,L=0)->Node(13,L=1),W=-0.2928,I=11333,E=1), Gene(Node(1,L=0)->Node(11,L=1),W=-0.8608,I=11534,E=1), Gene(Node(0,L=0)->Node(12,L=1),W=0.2116,I=14312,E=1), Gene(Node(3,L=0)->Node(11,L=1),W=0.7277,I=14882,E=1)]

# %%
game = Add4Game(100)
wins = game.play_game([best_agent], print_game=False)
print(wins)
print(best_agent.fitness)
# Out:
# [15]
# 93.125

# %%
with open('agent_wins.pickle', 'rb') as handle:
    agent_wins = pickle.load(handle)
plt.plot(range(1, len(agent_wins) + 1), agent_wins, color='Orange')
plt.show()

# %%
with open('num_innovations.pickle', 'rb') as handle:
    num_innovations = pickle.load(handle)
plt.plot(range(1, len(num_innovations) + 1), num_innovations, color='Orange')
plt.show()

# %%
with open('num_species.pickle', 'rb') as handle:
    num_species = pickle.load(handle)
plt.plot(range(1, len(num_species) + 1), num_species, color='Orange')
plt.show()

# %%
with open('avg_fitness.pickle', 'rb') as handle:
    avg_fitness = pickle.load(handle)
plt.plot(range(1, len(avg_fitness) + 1), avg_fitness, color='Orange')
plt.show()

# %%
with open('max_fitness.pickle', 'rb') as handle:
    max_fitness = pickle.load(handle)
plt.plot(range(1, len(max_fitness) + 1), max_fitness, color='Orange')
plt.show()
